# %%
# %gui tk
import numpy as np
import pandas as pd
import tkinter as tk

from pandastable import Table
from tkinter import ttk
from tkinter import *
import tkinter.messagebox as messagebox
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('ratings.csv')
#data.head(10)
Movie_genre=pd.read_csv('moviesData.csv')
#Movie_genre.head(10)
data=data.merge(Movie_genre,on='MovieID',how='left')
#data.head(10)
Average_ratings=pd.DataFrame(data.groupby('MovieTitle')['Rating'].mean())
#Average_ratings.head(10)
Average_ratings['Total_rating']=pd.DataFrame(data.groupby('MovieTitle')['Rating'].count())
#Average_ratings.head(10)
MovieUser=data.pivot_table(index='UserID',columns='MovieTitle',values='Rating')
#MovieUser.head(10)

# %%
# %gui tk
from tkinter import *
import tkinter.messagebox as messagebox
import warnings
warnings.filterwarnings("ignore")


window=tk.Tk()
window.title('Movie Recommendation')
window.geometry('600x600')

df=pd.read_csv('movies.csv')
df.sort_values('MovieTitle',inplace=True)
val=[]
val=df['MovieTitle'].values.tolist()

def selectedFunction():
    l2.configure(text=ComboGrp1.get())
    v=l2.cget('text')
    correlations=MovieUser.corrwith(MovieUser[v])#compute pairwise correlation between rows and columns.
    #print(correlations.head(20))
    recommendation=pd.DataFrame(correlations,columns=['CORRELATION'])
    recommendation.dropna(inplace=True)
    recommendation=recommendation.join(Average_ratings['Total_rating'])
    #print(recommendation.head(10))

    rec=recommendation[recommendation['Total_rating']>100].sort_values('CORRELATION',ascending=False).reset_index()
    rec=rec.merge(Movie_genre,on='MovieTitle',how='left')
    rc=rec.head()
    
    frame=tk.Frame(window)
    frame.grid()
    
    pt=Table(frame,dataframe=rc,showstatusbar=True)
    pt.show()
    ############
    
    ############
    #print(rec.head(10))

l1=ttk.Label(window,text='select movie name').grid(column=0,row=0)
v=tk.StringVar()
ComboGrp1=ttk.Combobox(window,width=70)
ComboGrp1.grid(column=0,row=1)
ComboGrp1['values']=(val)
#ComboGrp1.current(0)

btn1=ttk.Button(window,text='submit',command=selectedFunction)
btn1.grid(column=0,row=2)
l2=ttk.Label(window,text='')
l2.grid(column=0,row=3)




#correlations=MovieUser.corrwith(MovieUser[l2.text])#compute pairwise correlation between rows and columns.
#correlations.head(10)



window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-3-d00ac4af7252>", line 35, in selectedFunction
#     pt.show()
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\core.py", line 306, in show
#     self.statusbar = statusBar(self.parentframe, self)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\core.py", line 3709, in __init__
#     addButton(fr, 'Contract Cols', self.parentapp.contractColumns, img, 'contract columns', side=LEFT, padding=1)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\dialogs.py", line 245, in addButton
#     image=img, compound=compound, padding=padding)
#   File "D:\Anacondainstalled\lib\tkinter\ttk.py", line 614, in __init__
#     Widget.__init__(self, master, "ttk::button", kw)
#   File "D:\Anacondainstalled\lib\tkinter\ttk.py", line 559, in __init__
#     tkinter.Widget.__init__(self, master, widgetname, kw=kw)
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 2299, in __init__
#     (widgetName, self._w) + extra + self._options(cnf))
# _tkinter.TclError: image "pyimage1" doesn't exist
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\core.py", line 318, in resized
#     if self.currwidth !=self.parentframe.winfo_width() or \
# AttributeError: 'Table' object has no attribute 'currwidth'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 327, in handle_mouse_move
#     if x > self.tablewidth+w:
# AttributeError: 'ColumnHeader' object has no attribute 'tablewidth'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 327, in handle_mouse_move
#     if x > self.tablewidth+w:
# AttributeError: 'ColumnHeader' object has no attribute 'tablewidth'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 327, in handle_mouse_move
#     if x > self.tablewidth+w:
# AttributeError: 'ColumnHeader' object has no attribute 'tablewidth'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 281, in handle_mouse_drag
#     if self.atdivider == 1:
# AttributeError: 'ColumnHeader' object has no attribute 'atdivider'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 281, in handle_mouse_drag
#     if self.atdivider == 1:
# AttributeError: 'ColumnHeader' object has no attribute 'atdivider'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 281, in handle_mouse_drag
#     if self.atdivider == 1:
# AttributeError: 'ColumnHeader' object has no attribute 'atdivider'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 281, in handle_mouse_drag
#     if self.atdivider == 1:
# AttributeError: 'ColumnHeader' object has no attribute 'atdivider'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\headers.py", line 240, in handle_left_release
#     if self.atdivider == 1:
# AttributeError: 'ColumnHeader' object has no attribute 'atdivider'
# could not sort
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anacondainstalled\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\Anacondainstalled\lib\site-packages\pandastable\core.py", line 318, in resized
#     if self.currwidth !=self.parentframe.winfo_width() or \
# AttributeError: 'Table' object has no attribute 'currwidth'
